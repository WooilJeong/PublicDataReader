# %%
import PublicDataReader as pdr

# %%
apt = pdr.AptTransactionReader("fqwy4gYoV4rY1zFgyoOC8hhBvJ%2FNastyYrmtEzAhHRYxQriYAXzMSCfDCIXLs8n5HC2Sz6xXDSdx9Y1JHHADVQ%3D%3D")

# %%
import os
print(os.getcwd())
# Out:
# /Users/wooil/github/PublicDataReader

# %%
apt.CodeFinder("백현동")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-14f6d22588af> in <module>
# ----> 1 apt.CodeFinder("백현동")
#
# ~/github/PublicDataReader/PublicDataReader/PublicDataPortal/AptTransaction.py in CodeFinder(self, name)
#      17         API에 사용할 구 별 코드를 조회하는 메소드이며, 문자열 지역 명을 입력받고, 조회 결과를 Pandas DataFrame형식으로 출력합니다.
#      18         '''
# ---> 19         code = pd.read_csv("./법정동코드 전체자료.txt", encoding='cp949', sep='\t')
#      20         code = code.loc[code['폐지여부']=='존재']
#      21         code['법정구코드'] = list(map(lambda a: str(a)[:5], list(code['법정동코드'])))
#
# ...

# %%
apt.DataReader("11110", '201911')
# Out:
#      지역코드   법정동        거래일         아파트      지번     전용면적   층  건축년도    거래금액
# 0   11110  명륜2가 2019-11-02         아남3     237    47.43   6  1999   55000
# 1   11110   무악동 2019-11-01          현대      82       60   7  2000   66800
# 2   11110   무악동 2019-11-06          현대      82       60   4  2000   67190
# 3   11110   무악동 2019-11-19   인왕산2차아이파크      88  84.0284  13  2015   98000
# 4   11110   무악동 2019-11-23          현대      82    84.92   2  2000   84980
# 5   11110   숭인동 2019-11-12     삼전솔하임2차  296-19       15   7  2012   12800
# 6   11110   숭인동 2019-11-13   종로청계힐스테이트     766  59.9426   1  2009   54850
# 7   11110   익선동 2019-11-19      현대뜨레비앙      55     45.5   4  2003   28850
# 8   11110   익선동 2019-11-20      현대뜨레비앙      55     28.1   8  2003   22000
# 9   11110   인의동 2019-11-05     효성쥬얼리시티    48-2     84.7  18  2006   68500
# 10  11110   창신동 2019-11-02   MID그린(4동)   601-5    59.55   3  2002   29990
# 11  11110   창신동 2019-11-08          두산     232     84.9   6  1999   82500
# ...
